# %%
! pip install matplotlib

# %%
! pip install pandas

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Import the LISS data
LISS = pd.read_csv('data_subsample.csv')

# inspect
#print(LISS.head())

# inspect the variable requested
print(LISS['cf19l393'])
plt.hist(LISS['cf19l393'])
plt.show()
# Out:
# 0      02-09-2019
# 1      02-09-2019
# 2      16-09-2019
# 3      17-09-2019
# 4      21-09-2019
#           ...
# 995    10-09-2019
# 996    13-10-2019
# 997    05-09-2019
# 998    17-10-2019
# 999    16-09-2019
# Name: cf19l393, Length: 1000, dtype: object
